# %%
import pandas as pd
import sys
import altair as alt
alt.data_transformers.disable_max_rows()

sys.path.append("..")
from data_generation_scripts.utils import check_rate_limit, get_core_users_repos
from data_generation_scripts.generate_user_repos_interactions import get_user_repo_activities
from data_generation_scripts.generate_user_users_interactions import get_user_users_activities
from data_generation_scripts.generate_user_metadata import check_total_results

# %%
rates_df = check_rate_limit()

# %% [markdown]
# ### Get Initial Users

# %%
core_users, core_repos = get_core_users_repos()

# %% [markdown]
# ### Get Missing Counts

# %%
cols_dict ={'followers': 'followers', 'following': 'following', 'public_repos': 'public_repos', 'public_gists': 'public_gists', 'star_count': 'starred_url', 'subscription_count': 'subscriptions_url', 'organization_count': 'organizations_url'}
cols_df = pd.DataFrame(cols_dict.items(), columns=['col_name', 'col_url'])
cols = cols_df.col_name.tolist()
reverse_cols = cols[::-1]
cols_df.to_csv("../data/metadata_files/user_url_cols.csv", index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for index, row in cols_df.iterrows():
    if (row['col_name'] not in core_users.columns) or (core_users[core_users[row.col_name].isna()].shape[0] > 0):
        if 'url' in row.col_url:
            print(f'Getting {row.col_name} for core users')
            core_users = check_total_results(core_users, row.col_name, row.col_url)
        else:
            print(f'Issues with {row.col_name} for core users')
# Out:
# Getting organization_count for core users
# Getting total results for each user:   0%|          | 4/4387 [00:00<08:53,  8.21it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:   0%|          | 5/4387 [02:00<43:30:13, 35.74s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/e-gius/orgs?per_page=1
# Getting total results for each user:   9%|▉         | 398/4387 [03:04<10:37,  6.26it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:   9%|▉         | 399/4387 [05:05<40:09:58, 36.26s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/loveJasmine/orgs?per_page=1
# Getting total results for each user:  12%|█▏        | 508/4387 [05:23<10:26,  6.19it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  12%|█▏        | 509/4387 [07:23<39:06:03, 36.30s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/audrie-z/orgs?per_page=1
# Getting total results for each user:  12%|█▏        | 528/4387 [07:26<14:18,  4.49it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  12%|█▏        | 529/4387 [09:27<38:55:54, 36.33s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/labrec/orgs?per_page=1
# Getting total results for each user:  14%|█▎        | 598/4387 [09:38<10:01,  6.30it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  14%|█▎        | 599/4387 [11:38<38:09:23, 36.26s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/nanguiyan/orgs?per_page=1
# Getting total results for each user:  16%|█▌        | 699/4387 [11:55<10:34,  5.82it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  16%|█▌        | 700/4387 [13:56<37:08:54, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/EDiLD/orgs?per_page=1
# Getting total results for each user:  21%|██        | 916/4387 [14:30<09:17,  6.22it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  21%|██        | 917/4387 [16:31<34:58:05, 36.28s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/niko2342/orgs?per_page=1
# Getting total results for each user:  24%|██▍       | 1043/4387 [16:51<09:12,  6.06it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  24%|██▍       | 1044/4387 [18:51<33:41:18, 36.28s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/zhp562176325/orgs?per_page=1
# Getting total results for each user:  29%|██▉       | 1281/4387 [19:31<08:00,  6.47it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  29%|██▉       | 1282/4387 [21:31<31:16:38, 36.26s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/stefanpernes/orgs?per_page=1
# Getting total results for each user:  40%|████      | 1771/4387 [22:50<07:15,  6.00it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  40%|████      | 1772/4387 [24:50<26:20:45, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/dhandlib/orgs?per_page=1
# Getting total results for each user:  45%|████▍     | 1955/4387 [25:19<06:31,  6.21it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  45%|████▍     | 1956/4387 [27:20<24:29:33, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/dtdh/orgs?per_page=1
# Getting total results for each user:  47%|████▋     | 2061/4387 [27:37<06:09,  6.29it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  47%|████▋     | 2062/4387 [29:37<23:25:18, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/CDH-DevTeam/orgs?per_page=1
# Getting total results for each user:  49%|████▉     | 2139/4387 [29:50<05:54,  6.34it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  49%|████▉     | 2140/4387 [31:50<22:38:22, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/TimStrohmayer/orgs?per_page=1
# Getting total results for each user:  50%|█████     | 2201/4387 [32:00<05:46,  6.30it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  50%|█████     | 2202/4387 [34:00<22:00:45, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/mtaitano/orgs?per_page=1
# Getting total results for each user:  52%|█████▏    | 2274/4387 [34:12<05:37,  6.27it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  52%|█████▏    | 2275/4387 [36:12<21:16:39, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/orestes824/orgs?per_page=1
# Getting total results for each user:  53%|█████▎    | 2314/4387 [36:18<05:23,  6.41it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  53%|█████▎    | 2315/4387 [38:19<20:52:20, 36.26s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/HumanidadesDigitales/orgs?per_page=1
# Getting total results for each user:  53%|█████▎    | 2334/4387 [38:22<06:58,  4.90it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  53%|█████▎    | 2335/4387 [40:23<20:41:43, 36.31s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/gsimone83/orgs?per_page=1
# Getting total results for each user:  54%|█████▎    | 2349/4387 [40:25<14:05,  2.41it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  54%|█████▎    | 2350/4387 [42:25<20:37:22, 36.45s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/luca-porcu/orgs?per_page=1
# Getting total results for each user:  66%|██████▌   | 2874/4387 [43:51<03:51,  6.53it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  66%|██████▌   | 2875/4387 [45:52<15:13:42, 36.26s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/ChessPiece21/orgs?per_page=1
# Getting total results for each user:  81%|████████  | 3540/4387 [47:41<02:32,  5.56it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  81%|████████  | 3541/4387 [49:42<8:31:21, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/awingo-mckula/orgs?per_page=1
# Getting total results for each user:  90%|█████████ | 3959/4387 [50:47<01:02,  6.84it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  90%|█████████ | 3960/4387 [52:47<4:18:08, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/lineasyparrafos/orgs?per_page=1
# Getting total results for each user:  93%|█████████▎| 4063/4387 [53:03<00:50,  6.36it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  93%|█████████▎| 4064/4387 [55:04<3:15:14, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/Hizkie/orgs?per_page=1
# Getting total results for each user:  97%|█████████▋| 4260/4387 [55:37<00:20,  6.23it/s]
# response code: 404. hit rate limiting. trying to sleep...
# Getting total results for each user:  97%|█████████▋| 4261/4387 [57:37<1:16:09, 36.27s/it]
# query failed twice with code 404. Failing URL: https://api.github.com/users/hdcaicyt/orgs?per_page=1
# Getting total results for each user: 100%|██████████| 4387/4387 [57:58<00:00,  1.26it/s]

# %%
core_users.to_csv("../data/derived_files/core_users.csv", index=False)

# %%
core_users['cleaned_date'] = pd.to_datetime(core_users['created_at'])
core_users['year'] = core_users['cleaned_date'].dt.year

# %%
core_users.organization_count = core_users.organization_count.astype(int)
core_users.public_gists = core_users.public_gists.astype(int)
core_users.public_repos = core_users.public_repos.astype(int)
core_users.star_count = core_users.star_count.astype(int)
core_users.subscription_count = core_users.subscription_count.astype(int)

# %%
alt.Chart(core_users[cols + ['year']]).mark_circle().encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color=alt.Color('year:N', scale=alt.Scale(scheme='plasma')),
    # tooltip=[] 
).properties(
    width=125,
    height=125
).repeat(
    row=cols,
    column=reverse_cols
)
# Out:
# alt.RepeatChart(...)

# %%
core_users.organization_count.sum() / 5000
# Out:
# 0.5482
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Get User Followers

# %%
user_users_output_path = "../data/large_files/join_files/user_followers_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "followers_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_followers_df, user_df = get_user_users_activities(core_users,user_users_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)

# %% [markdown]
# ### Get User Following

# %%
user_users_output_path = "../data/large_files/join_files/user_following_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "following_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_following_df, user_df = get_user_users_activities(core_users, user_users_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)

# %% [markdown]
# ### Get User Stars

# %%
user_users_output_path = "../data/large_files/join_files/user_starred_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "starred_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_starred_df, user_df = get_user_repo_activities(core_users,user_users_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)

# %% [markdown]
# ### Get User Repos

# %%
user_repos_output_path = "../data/large_files/join_files/user_repos_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "repos_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_repos_df, user_df = get_user_repo_activities(core_users,user_repos_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)

# %% [markdown]
# ### Get User Subscriptions

# %%
user_subscriptions_output_path = "../data/large_files/join_files/user_subscriptions_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "subscriptions_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_subscriptions_df, user_df = get_user_repo_activities(core_users,user_subscriptions_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)

# %% [markdown]
# ### Get User Organizations

# %%
user_organizations_output_path = "../data/large_files/join_files/user_organizations_join_dataset.csv"
users_output_path = "../data/entity_files/users_dataset.csv"
get_url_field = "organizations_url"
load_existing_files = True
overwrite_existing_temp_files = False

users_organizations_df, user_df = get_user_repo_activities(core_users,user_organizations_output_path, users_output_path, get_url_field, load_existing_files, overwrite_existing_temp_files)
