# %%
import pandas as pd
import sys
import os 
import altair as alt

sys.path.append("..")
from data_generation_scripts.utils import check_rate_limit, check_return_error_file, read_combine_files
from data_generation_scripts.generate_repo_metadata import get_repo_owners
from data_generation_scripts.generate_user_repos_interactions import get_user_repo_activities
from data_generation_scripts.generate_user_users_interactions import get_user_users_activities

# %%
user_df = pd.read_csv("../data/entity_files/users_dataset.csv")
repo_df = pd.read_csv('../data/large_files/entity_files/repos_dataset.csv', low_memory=False)
subset_repo_df = pd.read_csv('../data/entity_files/subset_repos_dataset_with_commits.csv')

# %%
original_owners = user_df[user_df.login.isin(subset_repo_df['owner.login'])]

# %% [markdown]
# ### Explore User Interactions

# %% [markdown]
# - contributors:
#   - has user columns with connection to repos with repo_full_name
# - forks:
#   - has repo columns with connection to repos with repo_full_name, and to user with owner

# %%
contributors_df = pd.read_csv('../data/join_files/repo_contributors_join_dataset.csv')
forks_df = pd.read_csv('../data/join_files/repo_forks_join_dataset.csv')
stargazers_df = pd.read_csv('../data/join_files/repo_stargazers_join_dataset.csv')
subscribers_df = pd.read_csv('../data/join_files/repo_subscribers_join_dataset.csv')
user_followers = pd.read_csv('../data/join_files/user_followers_join_dataset.csv')
user_following = pd.read_csv('../data/join_files/user_following_join_dataset.csv')

# %%
issues_comments_df = pd.read_csv('../data/large_files/join_files/issues_comments_join_dataset.csv', low_memory=False)
pulls_comments_df = pd.read_csv('../data/large_files/join_files/pulls_comments_join_dataset.csv', low_memory=False)
repo_issues_df = pd.read_csv('../data/large_files/join_files/repo_issues_join_dataset.csv', low_memory=False)
repo_pulls_df = pd.read_csv('../data/large_files/join_files/repo_pulls_join_dataset.csv', low_memory=False)

# %% [markdown]
# ### Explore Contributors

# %%
contributors_counts = contributors_df.login.value_counts().reset_index()
contributors_counts.columns = ['login', 'contributor_count']

alt.Chart(contributors_counts).mark_bar().encode(
    x=alt.X('contributor_count:Q'),
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
top_contributors = contributors_counts[contributors_counts.contributor_count > 2]
len(top_contributors)
# Out:
# 255

# %%
top_contributors_df = contributors_df[contributors_df.login.isin(top_contributors['login'])]

# %%
top_contributor_repos = top_contributors_df.repo_full_name.value_counts().reset_index()
top_contributor_repos.columns = ['repo_full_name', 'repo_contributor_count']

# %%
top_contributor_repos[top_contributor_repos.repo_contributor_count > 3].head(10)
# Out:
#                                       repo_full_name  repo_contributor_count
# 0                            cms633/cms633.github.io                      57
# 1                                   cms633/Fall-2019                      56
# 2                                   cms633/Fall-2018                      56
# 3        carpentries-incubator/sql-humanities-lesson                      24
# 4  carpentries-incubator/spreadsheet-humanities-l...                      23
# 5                         ComputeCanada/dh-carpentry                      22
# 6     carpentries-incubator/python-humanities-lesson                      21
# 7  carpentries-incubator/OpenRefine-humanities-le...                      20
# 8       UoMResearchIT/r-tidyverse-digital-humanities                      20
# 9                        programminghistorian/jekyll                      19

# %%
# commits_df = pd.read_csv('../data/temp/repo_commits_join_dataset/programminghistorianjekyll_repo_actors_commits_url.csv')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
commits_df[(commits_df['commit.message'].str.contains('twitter|Twitter', na=False)) & (commits_df['author.login'] == 'ZoeLeBlanc')]['commit.message'].tolist()
# Out:
# ['Merge pull request #2428 from programminghistorian/removing-twitter-commits\n\ncleaning up twitter commits hoping this time works',
#  'Merge pull request #1976 from programminghistorian/issue-1975\n\nadded 400 errors to htmlproofer ignore list to stop twitter from brea…']

# %%
top_ph_committers = commits_df['commit.author.name'].value_counts().reset_index().head(20)

# %%
top_ph_contributors = contributors_df[contributors_df.repo_full_name.str.contains('programminghistorian/jekyll')].sort_values(by='contributions', ascending=False)[['login', 'contributions']].head(20)

# %%
top_ph_committers.columns = ['login', 'commit_count']

# %%
import time
from urllib.parse import parse_qs
import pandas as pd
import requests
import os
from tqdm import tqdm
import apikey
import sys
sys.path.append("..")
from data_generation_scripts.utils import *
import shutil


auth_token = apikey.load("DH_GITHUB_DATA_PERSONAL_TOKEN")

auth_headers = {'Authorization': f'token {auth_token}','User-Agent': 'request'}

# %%
url = subset_repo_df[0:1].contributors_url.values[0]

# %%
url = 'https://api.github.com/repos/wildmary/Portfolio-DH/commits'

# %%
response = requests.get(url, headers=auth_headers)

# %%
response_df = pd.json_normalize(response.json())

# %%
query = response_df[0:1].url.values[0]

# %%
query = response_df.url.values[0]

# %%
response_commit = requests.get(query, headers=auth_headers)

# %%
response_commit_df = pd.json_normalize(response_commit.json())

# %%
response_commit_df
# Out:
#                                         sha  \
# 0  a4cb55355ba8fbe6cf19691600d19524fc110aef
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjgzOTAzMjQxOmE0Y2I1NTM1NWJhOGZiZT...
#
#                                                  url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                             html_url  \
# 0  https://github.com/wildmary/Portfolio-DH/commi...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                              parents  \
# 0  [{'sha': '3bb3421fa786b5762d2cef6af5846ce0254a...
#
#                                                files commit.author.name  \
# 0  [{'sha': '666217c728b52486a3a55f0d406aec1a4ef7...     Mary Levchenko
#
#   commit.author.email    commit.author.date  ...  \
# 0  wildmary@yandex.ru  2020-07-31T02:24:21Z  ...
#
#                          committer.subscriptions_url  \
# 0  https://api.github.com/users/web-flow/subscrip...
#
#                   committer.organizations_url  \
# 0  https://api.github.com/users/web-flow/orgs
#
#                            committer.repos_url  \
# 0  https://api.github.com/users/web-flow/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/web-flow/events{/...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/web-flow/received...           User
#
#   committer.site_admin  stats.total  stats.additions stats.deletions
# 0                False            1                1               0
#
# [1 rows x 61 columns]

# %%
join_cols = list(set(response_commit_df.columns) & set(response_df.columns))

# %%
set(response_commit_df.columns) - set(response_df.columns)
# Out:
# {'files', 'stats.additions', 'stats.deletions', 'stats.total'}

# %%
test = pd.read_csv('../data/temp/repo_commits_join_dataset/wildmaryPortfolio-DH_repo_actors_commits_url.csv')

# %%
test
# Out:
#                                          sha  \
# 0   a4cb55355ba8fbe6cf19691600d19524fc110aef
# 1   3bb3421fa786b5762d2cef6af5846ce0254a8bd1
# 2   88bca5394425f3ab43dd5e3acb54b01ad3f4c3d4
# 3   9142bdd3534f3d5145f048d24f0ea823c247e20e
# 4   d2eb752a2e8e605c0395d4e5bd1b45a1ec03aae9
# 5   86057fe64bb634209a352237c0ab4481aad17d36
# 6   10558c74586b7475396db4760edb14d5d1e0ac07
# 7   0552821a246a28502c8a7c289df100f09c7a95ec
# 8   d3e64f6f28b0551e60b32c6e60da22cdfefe528d
# 9   436b95cfa867c8867e90f6b72e74ec688404a3ff
# 10  92d50e814a98ab1c661052ee686fd099c2b34e46
# 11  338b99a6c26ab8979326da8747f3eb9c1a245e95
# 12  4d242ff719f5c0febd00e2d50bdf42628c427826
# 13  9251b3eccb5818723d0b6de9a289d7ee2e9a22a3
# 14  00df576ba028e5090777363010e7a9c5997acb39
#
#                                               node_id  \
# 0   MDY6Q29tbWl0MjgzOTAzMjQxOmE0Y2I1NTM1NWJhOGZiZT...
# 1   MDY6Q29tbWl0MjgzOTAzMjQxOjNiYjM0MjFmYTc4NmI1Nz...
# 2   MDY6Q29tbWl0MjgzOTAzMjQxOjg4YmNhNTM5NDQyNWYzYW...
# 3   MDY6Q29tbWl0MjgzOTAzMjQxOjkxNDJiZGQzNTM0ZjNkNT...
# 4   MDY6Q29tbWl0MjgzOTAzMjQxOmQyZWI3NTJhMmU4ZTYwNW...
# 5   MDY6Q29tbWl0MjgzOTAzMjQxOjg2MDU3ZmU2NGJiNjM0Mj...
# 6   MDY6Q29tbWl0MjgzOTAzMjQxOjEwNTU4Yzc0NTg2Yjc0Nz...
# 7   MDY6Q29tbWl0MjgzOTAzMjQxOjA1NTI4MjFhMjQ2YTI4NT...
# 8   MDY6Q29tbWl0MjgzOTAzMjQxOmQzZTY0ZjZmMjhiMDU1MW...
# 9   MDY6Q29tbWl0MjgzOTAzMjQxOjQzNmI5NWNmYTg2N2M4OD...
# 10  MDY6Q29tbWl0MjgzOTAzMjQxOjkyZDUwZTgxNGE5OGFiMW...
# 11  MDY6Q29tbWl0MjgzOTAzMjQxOjMzOGI5OWE2YzI2YWI4OT...
# 12  MDY6Q29tbWl0MjgzOTAzMjQxOjRkMjQyZmY3MTlmNWMwZm...
# 13  MDY6Q29tbWl0MjgzOTAzMjQxOjkyNTFiM2VjY2I1ODE4Nz...
# 14  MDY6Q29tbWl0MjgzOTAzMjQxOjAwZGY1NzZiYTAyOGU1MD...
#
#                                                   url  \
# 0   https://api.github.com/repos/wildmary/Portfoli...
# 1   https://api.github.com/repos/wildmary/Portfoli...
# 2   https://api.github.com/repos/wildmary/Portfoli...
# 3   https://api.github.com/repos/wildmary/Portfoli...
# 4   https://api.github.com/repos/wildmary/Portfoli...
# 5   https://api.github.com/repos/wildmary/Portfoli...
# 6   https://api.github.com/repos/wildmary/Portfoli...
# 7   https://api.github.com/repos/wildmary/Portfoli...
# 8   https://api.github.com/repos/wildmary/Portfoli...
# 9   https://api.github.com/repos/wildmary/Portfoli...
# 10  https://api.github.com/repos/wildmary/Portfoli...
# 11  https://api.github.com/repos/wildmary/Portfoli...
# 12  https://api.github.com/repos/wildmary/Portfoli...
# 13  https://api.github.com/repos/wildmary/Portfoli...
# 14  https://api.github.com/repos/wildmary/Portfoli...
#
#                                              html_url  \
# 0   https://github.com/wildmary/Portfolio-DH/commi...
# 1   https://github.com/wildmary/Portfolio-DH/commi...
# 2   https://github.com/wildmary/Portfolio-DH/commi...
# 3   https://github.com/wildmary/Portfolio-DH/commi...
# 4   https://github.com/wildmary/Portfolio-DH/commi...
# 5   https://github.com/wildmary/Portfolio-DH/commi...
# 6   https://github.com/wildmary/Portfolio-DH/commi...
# 7   https://github.com/wildmary/Portfolio-DH/commi...
# 8   https://github.com/wildmary/Portfolio-DH/commi...
# 9   https://github.com/wildmary/Portfolio-DH/commi...
# 10  https://github.com/wildmary/Portfolio-DH/commi...
# 11  https://github.com/wildmary/Portfolio-DH/commi...
# 12  https://github.com/wildmary/Portfolio-DH/commi...
# 13  https://github.com/wildmary/Portfolio-DH/commi...
# 14  https://github.com/wildmary/Portfolio-DH/commi...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/wildmary/Portfoli...
# 1   https://api.github.com/repos/wildmary/Portfoli...
# 2   https://api.github.com/repos/wildmary/Portfoli...
# 3   https://api.github.com/repos/wildmary/Portfoli...
# 4   https://api.github.com/repos/wildmary/Portfoli...
# 5   https://api.github.com/repos/wildmary/Portfoli...
# 6   https://api.github.com/repos/wildmary/Portfoli...
# 7   https://api.github.com/repos/wildmary/Portfoli...
# 8   https://api.github.com/repos/wildmary/Portfoli...
# 9   https://api.github.com/repos/wildmary/Portfoli...
# 10  https://api.github.com/repos/wildmary/Portfoli...
# 11  https://api.github.com/repos/wildmary/Portfoli...
# 12  https://api.github.com/repos/wildmary/Portfoli...
# 13  https://api.github.com/repos/wildmary/Portfoli...
# 14  https://api.github.com/repos/wildmary/Portfoli...
#
#                                               parents commit.author.name  \
# 0   [{'sha': '3bb3421fa786b5762d2cef6af5846ce0254a...     Mary Levchenko
# 1   [{'sha': '88bca5394425f3ab43dd5e3acb54b01ad3f4...     Mary Levchenko
# 2   [{'sha': '9142bdd3534f3d5145f048d24f0ea823c247...     Mary Levchenko
# 3   [{'sha': 'd2eb752a2e8e605c0395d4e5bd1b45a1ec03...     Mary Levchenko
# 4   [{'sha': '86057fe64bb634209a352237c0ab4481aad1...     Mary Levchenko
# 5   [{'sha': '10558c74586b7475396db4760edb14d5d1e0...     Mary Levchenko
# 6   [{'sha': '0552821a246a28502c8a7c289df100f09c7a...     Mary Levchenko
# 7   [{'sha': 'd3e64f6f28b0551e60b32c6e60da22cdfefe...     Mary Levchenko
# 8   [{'sha': '436b95cfa867c8867e90f6b72e74ec688404...     Mary Levchenko
# 9   [{'sha': '92d50e814a98ab1c661052ee686fd099c2b3...     Mary Levchenko
# 10  [{'sha': '338b99a6c26ab8979326da8747f3eb9c1a24...     Mary Levchenko
# 11  [{'sha': '4d242ff719f5c0febd00e2d50bdf42628c42...     Mary Levchenko
# 12  [{'sha': '9251b3eccb5818723d0b6de9a289d7ee2e9a...     Mary Levchenko
# 13  [{'sha': '00df576ba028e5090777363010e7a9c5997a...     Mary Levchenko
# 14                                                 []     Mary Levchenko
#
#    commit.author.email    commit.author.date commit.committer.name  ...  \
# 0   wildmary@yandex.ru  2020-07-31T02:24:21Z                GitHub  ...
# 1   wildmary@yandex.ru  2020-07-31T02:23:02Z                GitHub  ...
# 2   wildmary@yandex.ru  2020-07-31T02:20:25Z                GitHub  ...
# 3   wildmary@yandex.ru  2020-07-31T02:14:34Z                GitHub  ...
# 4   wildmary@yandex.ru  2020-07-31T01:48:50Z                GitHub  ...
# 5   wildmary@yandex.ru  2020-07-31T01:34:21Z                GitHub  ...
# 6   wildmary@yandex.ru  2020-07-31T01:33:37Z                GitHub  ...
# 7   wildmary@yandex.ru  2020-07-31T01:30:26Z                GitHub  ...
# 8   wildmary@yandex.ru  2020-07-31T01:04:43Z                GitHub  ...
# 9   wildmary@yandex.ru  2020-07-31T01:04:05Z                GitHub  ...
# 10  wildmary@yandex.ru  2020-07-31T00:42:48Z                GitHub  ...
# 11  wildmary@yandex.ru  2020-07-31T00:22:28Z                GitHub  ...
# 12  wildmary@yandex.ru  2020-07-31T00:21:18Z                GitHub  ...
# 13  wildmary@yandex.ru  2020-07-31T00:19:19Z                GitHub  ...
# 14  wildmary@yandex.ru  2020-07-31T00:16:57Z                GitHub  ...
#
#    committer.site_admin                                              files  \
# 0                 False  [{'sha': '666217c728b52486a3a55f0d406aec1a4ef7...
# 1                 False  [{'sha': '4bbb2fdf3f7c89bb7adcef3544f19223562e...
# 2                 False  [{'sha': '50a7a1202cd726d82010b2ecbc90932613d4...
# 3                 False  [{'sha': '9098d36566a2d0421859db64c3a82b30206c...
# 4                 False  [{'sha': 'f9cf0c83946bcda3b3653549d2395e230219...
# 5                 False  [{'sha': '5b81fbb60a084fdf763abe6f4d22eb95917a...
# 6                 False  [{'sha': 'dbf8289cc3c09c9f0acbfe13d4753cd26882...
# 7                 False  [{'sha': '2f4076f73e2c5e00a175c0cca023e89e1b42...
# 8                 False  [{'sha': '05c633952312fbe8ffc8d5ffd12149a9b651...
# 9                 False  [{'sha': '7f3d83668fd725139746a2a1d3ad3b7c4681...
# 10                False  [{'sha': '4f1e533ae841cb94392ef68952c6e65b43d2...
# 11                False  [{'sha': '7e2faf270d9dcb01ec9ee92dff4d5ffae237...
# 12                False  [{'sha': '7ea59af6532784a6debd7a41c35d104d8731...
# 13                False  [{'sha': 'b14f5e31a8a079cff52ec5cff87a959aa1af...
# 14                False  [{'sha': '7eba65a472a1721d8c75a33e631ca5416999...
#
#    stats.total stats.additions stats.deletions      repo_id  \
# 0            1               1               0  283903241.0
# 1           16              13               3  283903241.0
# 2            0               0               0  283903241.0
# 3            0               0               0  283903241.0
# 4           14              14               0  283903241.0
# 5            3               3               0  283903241.0
# 6           15              15               0  283903241.0
# 7            0               0               0  283903241.0
# 8            1               1               0  283903241.0
# 9            7               7               0  283903241.0
# 10           8               7               1  283903241.0
# 11           2               1               1  283903241.0
# 12           2               1               1  283903241.0
# 13          15              14               1  283903241.0
# 14           1               1               0  283903241.0
#
#                                              repo_url  \
# 0   https://api.github.com/repos/wildmary/Portfoli...
# 1   https://api.github.com/repos/wildmary/Portfoli...
# 2   https://api.github.com/repos/wildmary/Portfoli...
# 3   https://api.github.com/repos/wildmary/Portfoli...
# 4   https://api.github.com/repos/wildmary/Portfoli...
# 5   https://api.github.com/repos/wildmary/Portfoli...
# 6   https://api.github.com/repos/wildmary/Portfoli...
# 7   https://api.github.com/repos/wildmary/Portfoli...
# 8   https://api.github.com/repos/wildmary/Portfoli...
# 9   https://api.github.com/repos/wildmary/Portfoli...
# 10  https://api.github.com/repos/wildmary/Portfoli...
# 11  https://api.github.com/repos/wildmary/Portfoli...
# 12  https://api.github.com/repos/wildmary/Portfoli...
# 13  https://api.github.com/repos/wildmary/Portfoli...
# 14  https://api.github.com/repos/wildmary/Portfoli...
#
#                                repo_html_url         repo_full_name  \
# 0   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 1   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 2   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 3   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 4   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 5   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 6   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 7   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 8   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 9   https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 10  https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 11  https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 12  https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 13  https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
# 14  https://github.com/wildmary/Portfolio-DH  wildmary/Portfolio-DH
#
#                                           commits_url
# 0   https://api.github.com/repos/wildmary/Portfoli...
# 1   https://api.github.com/repos/wildmary/Portfoli...
# 2   https://api.github.com/repos/wildmary/Portfoli...
# 3   https://api.github.com/repos/wildmary/Portfoli...
# 4   https://api.github.com/repos/wildmary/Portfoli...
# 5   https://api.github.com/repos/wildmary/Portfoli...
# 6   https://api.github.com/repos/wildmary/Portfoli...
# 7   https://api.github.com/repos/wildmary/Portfoli...
# 8   https://api.github.com/repos/wildmary/Portfoli...
# 9   https://api.github.com/repos/wildmary/Portfoli...
# 10  https://api.github.com/repos/wildmary/Portfoli...
# 11  https://api.github.com/repos/wildmary/Portfoli...
# 12  https://api.github.com/repos/wildmary/Portfoli...
# 13  https://api.github.com/repos/wildmary/Portfoli...
# 14  https://api.github.com/repos/wildmary/Portfoli...
#
# [15 rows x 66 columns]

# %%
join_cols = list(set(response_commit_df.columns) - set(response_df.columns))
join_cols = join_cols + ['sha']
join_cols
# Out:
# ['files', 'stats.total', 'stats.additions', 'stats.deletions', 'sha']

# %%
dfs = []
for _, row in response_df[0:2].iterrows():
    query = row.url
    response_commit = requests.get(query, headers=auth_headers)
    response_commit_df = pd.json_normalize(response_commit.json())
    # response_commit_df = response_commit_df[join_cols].to_dict()
    row['files'] = response_commit_df['files'].values[0]
    row['stats.total'] = response_commit_df['stats.total'].values[0]
    row['stats.additions'] = response_commit_df['stats.additions'].values[0]
    row['stats.deletions'] = response_commit_df['stats.deletions'].values[0]
    updated_df = pd.DataFrame([row.to_dict()])
    dfs.append(updated_df)

# %%
pd.concat(dfs)
# Out:
#                                         sha  \
# 0  a4cb55355ba8fbe6cf19691600d19524fc110aef
# 0  3bb3421fa786b5762d2cef6af5846ce0254a8bd1
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjgzOTAzMjQxOmE0Y2I1NTM1NWJhOGZiZT...
# 0  MDY6Q29tbWl0MjgzOTAzMjQxOjNiYjM0MjFmYTc4NmI1Nz...
#
#                                                  url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                             html_url  \
# 0  https://github.com/wildmary/Portfolio-DH/commi...
# 0  https://github.com/wildmary/Portfolio-DH/commi...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                              parents commit.author.name  \
# 0  [{'sha': '3bb3421fa786b5762d2cef6af5846ce0254a...     Mary Levchenko
# 0  [{'sha': '88bca5394425f3ab43dd5e3acb54b01ad3f4...     Mary Levchenko
#
#   commit.author.email    commit.author.date commit.committer.name  ...  \
# 0  wildmary@yandex.ru  2020-07-31T02:24:21Z                GitHub  ...
# 0  wildmary@yandex.ru  2020-07-31T02:23:02Z                GitHub  ...
#
#                   committer.organizations_url  \
# 0  https://api.github.com/users/web-flow/orgs
# 0  https://api.github.com/users/web-flow/orgs
#
#                            committer.repos_url  \
# 0  https://api.github.com/users/web-flow/repos
# 0  https://api.github.com/users/web-flow/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/web-flow/events{/...
# 0  https://api.github.com/users/web-flow/events{/...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/web-flow/received...           User
# 0  https://api.github.com/users/web-flow/received...           User
#
#   committer.site_admin                                              files  \
# 0                False  [{'sha': '666217c728b52486a3a55f0d406aec1a4ef7...
# 0                False  [{'sha': '4bbb2fdf3f7c89bb7adcef3544f19223562e...
#
#    stats.total stats.additions stats.deletions
# 0            1               1               0
# 0           16              13               3
#
# [2 rows x 61 columns]

# %%
pd.merge(test, response_commit_df[join_cols], on='sha', how='left')
# Out:
#                                         sha  \
# 0  a4cb55355ba8fbe6cf19691600d19524fc110aef
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjgzOTAzMjQxOmE0Y2I1NTM1NWJhOGZiZT...
#
#                                                  url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                             html_url  \
# 0  https://github.com/wildmary/Portfolio-DH/commi...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/wildmary/Portfoli...
#
#                                              parents commit.author.name  \
# 0  [{'sha': '3bb3421fa786b5762d2cef6af5846ce0254a...     Mary Levchenko
#
#   commit.author.email    commit.author.date commit.committer.name  ...  \
# 0  wildmary@yandex.ru  2020-07-31T02:24:21Z                GitHub  ...
#
#                   committer.organizations_url  \
# 0  https://api.github.com/users/web-flow/orgs
#
#                            committer.repos_url  \
# 0  https://api.github.com/users/web-flow/repos
#
#                                 committer.events_url  \
# 0  https://api.github.com/users/web-flow/events{/...
#
#                        committer.received_events_url committer.type  \
# 0  https://api.github.com/users/web-flow/received...           User
#
#   committer.site_admin                                              files  \
# 0                False  [{'sha': '666217c728b52486a3a55f0d406aec1a4ef7...
#
#    stats.deletions stats.additions stats.total
# 0                0               1           1
#
# [1 rows x 61 columns]

# %%
response_df.to_dict()
# Out:
# {'login': {0: 'wildmary'},
#  'id': {0: 38806620},
#  'node_id': {0: 'MDQ6VXNlcjM4ODA2NjIw'},
#  'avatar_url': {0: 'https://avatars.githubusercontent.com/u/38806620?v=4'},
#  'gravatar_id': {0: ''},
#  'url': {0: 'https://api.github.com/users/wildmary'},
#  'html_url': {0: 'https://github.com/wildmary'},
#  'followers_url': {0: 'https://api.github.com/users/wildmary/followers'},
#  'following_url': {0: 'https://api.github.com/users/wildmary/following{/other_user}'},
#  'gists_url': {0: 'https://api.github.com/users/wildmary/gists{/gist_id}'},
#  'starred_url': {0: 'https://api.github.com/users/wildmary/starred{/owner}{/repo}'},
#  'subscriptions_url': {0: 'https://api.github.com/users/wildmary/subscriptions'},
#  'organizations_url': {0: 'https://api.github.com/users/wildmary/orgs'},
#  'repos_url': {0: 'https://api.github.com/users/wildmary/repos'},
#  'events_url': {0: 'https://api.github.com/users/wildmary/events{/privacy}'},
#  'received_events_url': {0: 'https://api.github.com/users/wildmary/received_events'},
#  'type': {0: 'User'},
#  'site_admin': {0: False},
#  'contributions': {0: 15}}

# %%
response_user_df.to_dict()
# Out:
# {'login': {0: 'wildmary'},
#  'id': {0: 38806620},
#  'node_id': {0: 'MDQ6VXNlcjM4ODA2NjIw'},
#  'avatar_url': {0: 'https://avatars.githubusercontent.com/u/38806620?v=4'},
#  'gravatar_id': {0: ''},
#  'url': {0: 'https://api.github.com/users/wildmary'},
#  'html_url': {0: 'https://github.com/wildmary'},
#  'followers_url': {0: 'https://api.github.com/users/wildmary/followers'},
#  'following_url': {0: 'https://api.github.com/users/wildmary/following{/other_user}'},
#  'gists_url': {0: 'https://api.github.com/users/wildmary/gists{/gist_id}'},
#  'starred_url': {0: 'https://api.github.com/users/wildmary/starred{/owner}{/repo}'},
#  'subscriptions_url': {0: 'https://api.github.com/users/wildmary/subscriptions'},
#  'organizations_url': {0: 'https://api.github.com/users/wildmary/orgs'},
#  'repos_url': {0: 'https://api.github.com/users/wildmary/repos'},
#  'events_url': {0: 'https://api.github.com/users/wildmary/events{/privacy}'},
#  'received_events_url': {0: 'https://api.github.com/users/wildmary/received_events'},
#  'type': {0: 'User'},
#  'site_admin': {0: False},
#  'name': {0: 'Mary Levchenko'},
#  'company': {0: None},
#  'blog': {0: ''},
#  'location': {0: None},
#  'email': {0: None},
#  'hireable': {0: None},
#  'bio': {0: None},
#  'twitter_username': {0: None},
#  'public_repos': {0: 18},
#  'public_gists': {0: 0},
#  'followers': {0: 1},
#  'following': {0: 1},
#  'created_at': {0: '2018-04-28T07:57:50Z'},
#  'updated_at': {0: '2022-05-25T16:06:20Z'}}

# %%
user_df.columns
# Out:
# Index(['login', 'id', 'node_id', 'avatar_url', 'url', 'html_url',
#        'followers_url', 'following_url', 'gists_url', 'starred_url',
#        'subscriptions_url', 'organizations_url', 'repos_url', 'events_url',
#        'received_events_url', 'type', 'site_admin', 'public_repos',
#        'public_gists', 'followers', 'following', 'created_at', 'updated_at',
#        'starred_at', 'gravatar_id', 'contributions', 'pushed_at'],
#       dtype='object')

# %%
user_cols = pd.DataFrame(data=None, columns=response_user_df.columns)

# %%
user_cols.to_csv('../data/metadata_files/users_dataset_cols.csv', index=False)

# %%
set(user_df.columns.tolist()) & set(user_df.columns.tolist())
# Out:
# {'contributions', 'pushed_at', 'starred_at'}

# %%
user_df[0:1].to_dict()
# Out:
# {'login': {0: 'wildmary'},
#  'id': {0: 38806620},
#  'node_id': {0: 'MDQ6VXNlcjM4ODA2NjIw'},
#  'avatar_url': {0: 'https://avatars.githubusercontent.com/u/38806620?v=4'},
#  'url': {0: 'https://api.github.com/users/wildmary'},
#  'html_url': {0: 'https://github.com/wildmary'},
#  'followers_url': {0: 'https://api.github.com/users/wildmary/followers'},
#  'following_url': {0: 'https://api.github.com/users/wildmary/following{/other_user}'},
#  'gists_url': {0: 'https://api.github.com/users/wildmary/gists{/gist_id}'},
#  'starred_url': {0: 'https://api.github.com/users/wildmary/starred{/owner}{/repo}'},
#  'subscriptions_url': {0: 'https://api.github.com/users/wildmary/subscriptions'},
#  'organizations_url': {0: 'https://api.github.com/users/wildmary/orgs'},
#  'repos_url': {0: 'https://api.github.com/users/wildmary/repos'},
#  'events_url': {0: 'https://api.github.com/users/wildmary/events{/privacy}'},
#  'received_events_url': {0: 'https://api.github.com/users/wildmary/received_events'},
#  'type': {0: 'User'},
#  'site_admin': {0: False},
#  'public_repos': {0: 18.0},
#  'public_gists': {0: 0.0},
#  'followers': {0: 1.0},
#  'following': {0: 1.0},
#  'created_at': {0: '2018-04-28T07:57:50Z'},
#  'updated_at': {0: '2022-05-25T16:06:20Z'},
#  'starred_at': {0: nan},
#  'gravatar_id': {0: nan},
#  'contributions': {0: nan},
#  'pushed_at': {0: nan}}

# %%
contributors_df[0:1].to_dict()
# Out:
# {'login': {0: 'wildmary'},
#  'id': {0: 38806620},
#  'node_id': {0: 'MDQ6VXNlcjM4ODA2NjIw'},
#  'avatar_url': {0: 'https://avatars.githubusercontent.com/u/38806620?v=4'},
#  'gravatar_id': {0: nan},
#  'url': {0: 'https://api.github.com/users/wildmary'},
#  'html_url': {0: 'https://github.com/wildmary'},
#  'followers_url': {0: 'https://api.github.com/users/wildmary/followers'},
#  'following_url': {0: 'https://api.github.com/users/wildmary/following{/other_user}'},
#  'gists_url': {0: 'https://api.github.com/users/wildmary/gists{/gist_id}'},
#  'starred_url': {0: 'https://api.github.com/users/wildmary/starred{/owner}{/repo}'},
#  'subscriptions_url': {0: 'https://api.github.com/users/wildmary/subscriptions'},
#  'organizations_url': {0: 'https://api.github.com/users/wildmary/orgs'},
#  'repos_url': {0: 'https://api.github.com/users/wildmary/repos'},
#  'events_url': {0: 'https://api.github.com/users/wildmary/events{/privacy}'},
#  'received_events_url': {0: 'https://api.github.com/users/wildmary/received_events'},
#  'type': {0: 'User'},
#  'site_admin': {0: False},
#  'contributions': {0: 15},
#  'repo_id': {0: 283903241.0},
#  'repo_url': {0: 'https://api.github.com/repos/wildmary/Portfolio-DH'},
#  'repo_html_url': {0: 'https://github.com/wildmary/Portfolio-DH'},
#  'repo_full_name': {0: 'wildmary/Portfolio-DH'},
#  'contributors_url': {0: 'https://api.github.com/repos/wildmary/Portfolio-DH/contributors'},
#  'repo_query_time': {0: '2022-11-02'}}

# %%
pd.merge(top_ph_committers, top_ph_contributors, on='login', how='outer')
# Out:
#                    login  commit_count  contributions
# 0           Adam Crymble        1490.0            NaN
# 1        Matthew Lincoln         921.0            NaN
# 2            Anisa Hawes         789.0            NaN
# 3         Caleb McDaniel         397.0            NaN
# 4         Jennifer Isasi         351.0            NaN
# 5           Víctor Gayol         334.0            NaN
# 6           spapastamkou         290.0          442.0
# 7           Daniel Alves         273.0            NaN
# 8   Antonio Rojas Castro         270.0            NaN
# 9            James Baker         221.0            NaN
# 10            fred gibbs         196.0            NaN
# 11          Riva Quiroga         191.0            NaN
# 12          mariajoafana         182.0           70.0
# 13     Sofia Papastamkou         147.0            NaN
# 14            ZoeLeBlanc         141.0            NaN
# 15     W. Caleb McDaniel         140.0            NaN
# 16          Sarah Melton         134.0            NaN
# 17          ianmilligan1         128.0          194.0
# 18         Brandon Walsh          93.0            NaN
# 19      William J Turkel          75.0            NaN
# 20              acrymble           NaN         1364.0
# 21             mdlincoln           NaN          950.0
# 22           anisa-hawes           NaN          817.0
# 23                wcaleb           NaN          537.0
# 24         jenniferisasi           NaN          351.0
# 25              vgayolrs           NaN          334.0
# 26          arojascastro           NaN          270.0
# 27      DanielAlvesLABDH           NaN          265.0
# 28             fredgibbs           NaN          240.0
# 29           rivaquiroga           NaN          191.0
# 30              svmelton           NaN          150.0
# 31               walshbr           NaN          134.0
# 32             totoro501           NaN          108.0
# 33         jerielizabeth           NaN           86.0
# 34        williamjturkel           NaN           75.0
# 35       mariechristineb           NaN           57.0
# 36              tapar001           NaN           56.0

# %% [markdown]
# ### Explore User Issues

# %%
issues_comments_counts = issues_comments_df['user.login'].value_counts().reset_index()
issues_comments_counts.columns = ['login', 'issues_comments_count']

alt.Chart(issues_comments_counts).mark_bar().encode(
    x=alt.X('issues_comments_count:Q'),
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
top_issues_comments = issues_comments_counts[issues_comments_counts.issues_comments_count > 20]
len(top_issues_comments)
# Out:
# 278

# %%
top_issues_comments.head(20)
# Out:
#                       login  issues_comments_count
# 0                 rlskoeser                   3206
# 1                  acrymble                   2699
# 2                 drjwbaker                   1514
# 3           dependabot[bot]                   1441
# 4                 mdlincoln                   1392
# 5                     benel                   1331
# 6                    gissoo                   1002
# 7              thatbudakguy                    865
# 8                   walshbr                    848
# 9   dependabot-preview[bot]                    771
# 10            richmanrachel                    758
# 11             spapastamkou                    722
# 12             ianmilligan1                    710
# 13            jenniferisasi                    684
# 14                   ruebot                    680
# 15        codecov-commenter                    675
# 16              anisa-hawes                    650
# 17             arojascastro                    623
# 18                   thvitt                    590
# 19           gerritbruening                    554

# %%
top_issues_comments[top_issues_comments.login.str.contains('Zoe')]
# Out:
#          login  issues_comments_count
# 35  ZoeLeBlanc                    265

# %%
top_issues_comments[top_issues_comments.login.isin(top_contributors['login'])]
# Out:
#                login  issues_comments_count
# 0          rlskoeser                   3206
# 2          drjwbaker                   1514
# 3    dependabot[bot]                   1441
# 5              benel                   1331
# 6             gissoo                   1002
# 7       thatbudakguy                    865
# 8            walshbr                    848
# 20            dwhieb                    482
# 24             RJP43                    410
# 25              blms                    388
# 33            lenaMK                    298
# 41          ebeshero                    245
# 42         emchateau                    239
# 45      peterstadler                    222
# 48           bwhicks                    195
# 53          kmcelwee                    189
# 54        nilsreiter                    189
# 60    amandavisconti                    170
# 63            mnyrop                    149
# 74            vadekh                    113
# 76         gfranzini                    108
# 78           wenamun                    105
# 83       essepuntato                    100
# 85        taylorcate                     98
# 102          jarmoza                     78
# 113  marilenadaquino                     70
# 115  mchesterkadwell                     70
# 123    JonathanReeve                     59
# 136         haggis78                     51
# 154    arockenberger                     39
# 157      davanstrien                     37
# 168      rettinghaus                     35
# 169         hashmich                     35
# 181           versae                     33
# 203           smythp                     30
# 241      ericbrasiln                     25
# 248        bmschmidt                     24
# 262           mkgold                     22

# %%
top_issues_comments_df = issues_comments_df[issues_comments_df['user.login'].isin(top_issues_comments['login'])]

# %%
top_issues_comments_repos = top_issues_comments_df['repo_full_name'].value_counts().reset_index()
top_issues_comments_repos.columns = ['repo_full_name', 'repo_issues_comments_count']

# %%
top_issues_comments_repos[top_issues_comments_repos.repo_issues_comments_count > 20]
# Out:
#                    repo_full_name  repo_issues_comments_count
# 0     programminghistorian/jekyll                       12764
# 1            Princeton-CDH/geniza                        3369
# 2        Princeton-CDH/mep-django                        2526
# 3           archivesunleashed/aut                        1734
# 4             Hypertopic/Porphyry                        1414
# ..                            ...                         ...
# 95                  DH-Box/dh-usb                          28
# 96        JonathanReeve/corpus-db                          28
# 97             minicomp/wax_tasks                          27
# 98  lmullen/americas-public-bible                          23
# 99        Princeton-CDH/pemm-data                          22
#
# [100 rows x 2 columns]

# %%
user_dfs = []
repo_dfs = []
columns_dfs = []
dirs = ['../data/join_files', '../data/large_files/join_files']
for dir in dirs:
    for interal_dir, subdir, files in os.walk(dir):
        for f in files:
            if '.csv' in f:
                file_name = f.split('_join')[0]
                df = pd.read_csv(interal_dir + '/' + f, low_memory=False)
                col_df = pd.DataFrame([{'original_columns': df.columns.tolist(), 'file_type': file_name}])
                columns_dfs.append(col_df)
                if 'owner.login' in df.columns:
                    print('owner.login', file_name)
                if 'repo_full_name' in df.columns:
                    print('repo_full_name', file_name)
                if 'user_login' in df.columns:
                    print('user_login', file_name)
                if 'user.login' in df.columns:
                    print('user.login', file_name)
                # df['file_type'] = file_name
                # if 'repo_full_name' in df.columns :
                #     repo_dfs.append(df)
                # if 'user.login' in df.columns:
                #     user_dfs.append(df)

# %%
cols_df = pd.concat(columns_dfs)

# %%
cols_df.to_dict()

# %%
cols_df = cols_df.explode('original_columns')

# %%
cols_df.groupby(['original_columns', 'file_type']).size().reset_index().sort_values('original_columns')

# %%
user_join_df = pd.concat(user_dfs)
repo_join_df = pd.concat(repo_dfs)

# %%
user_join_df.columns.tolist()

# %%
stargazers_df = pd.read_csv('data/join_files/repo_stargazers_join_dataset.csv')

# %%
user_join_df.columns.tolist()

# %%
stargazers_df[0:1].to_dict()

# %%
user_join_df[0:1].to_dict()

# %%
repo_join_df[repo_join_df['user.following_url'].notna()].columns.tolist()
